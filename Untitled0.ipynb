# %%
print("Hello, my name is Hanan!")
print("I am learning Python using Google Colab.")
print("I am studying Machine Learning because I want to understand how computers can learn from data.")
# Out:
# Hello, my name is Hanan!
# I am learning Python using Google Colab.
# I am studying Machine Learning because I want to understand how computers can learn from data.

# %%
name = "Hanan"
age = 22
height = 1.60
is_student = True

print(name)
print(age)
print(height)
print(is_student)

print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# Hanan
# 22
# 1.6
# True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
a = 10
b = 4
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor division:", a // b)
print("Remainder:", a % b)
print("Power:", a ** b)
# Out:
# Addition: 14
# Subtraction: 6
# Multiplication: 40
# Division: 2.5
# Floor division: 2
# Remainder: 2
# Power: 10000

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
print("Hello", name)
print("Next year you will be", age + 1)
# Out:
# Enter your name: Hanan
# Enter your age: 22
# Hello Hanan
# Next year you will be 23

# %%
mark = float(input("Enter your mark: "))
if mark >= 60:
 print("Pass")
else:
  print("Fail")
# Out:
# Enter your mark: 80
# Pass

# %%
mark = float(input("Enter your mark: "))

if mark >= 90:
    print("A")
elif mark >= 80:
    print("B")
elif mark >= 70:
    print("C")
elif mark >= 60:
    print("D")
else:
    print("F")
# Out:
# Enter your mark: 80
# B

# %%
marks = [75, 82, 91, 68, 88]

print("Marks:", marks)
print("First mark:", marks[0])
print("Third mark:", marks[2])
print("Number of marks:", len(marks))
print("Total:", sum(marks))
print("Highest:", max(marks))
print("Lowest:", min(marks))
print("Average:", sum(marks) / len(marks))
# Out:
# Marks: [75, 82, 91, 68, 88]
# First mark: 75
# Third mark: 91
# Number of marks: 5
# Total: 404
# Highest: 91
# Lowest: 68
# Average: 80.8

# %%
temperature = [25.4, 26.1, 27.3, 28.0, 26.8]

print("Number of observations:", len(temperature))
print("Average temperature:", sum(temperature) / len(temperature))
print("Minimum temperature:", min(temperature))
print("Maximum temperature:", max(temperature))
# Out:
# Number of observations: 5
# Average temperature: 26.72
# Minimum temperature: 25.4
# Maximum temperature: 28.0

# %%
study_hours = [1, 2, 3, 4, 5, 6, 7]
marks = [50, 55, 60, 65, 72, 80, 88]

for i in range(len(study_hours)):
    print("Study hours:", study_hours[i], "Marks:", marks[i])

print("Feature: study_hours")
print("Target: marks")
# Out:
# Study hours: 1 Marks: 50
# Study hours: 2 Marks: 55
# Study hours: 3 Marks: 60
# Study hours: 4 Marks: 65
# Study hours: 5 Marks: 72
# Study hours: 6 Marks: 80
# Study hours: 7 Marks: 88
# Feature: study_hours
# Target: marks

# %%
study_hours = [1, 2, 3, 4, 5, 6, 7]
marks = [50, 55, 60, 65, 72, 80, 88]

for i in range(len(study_hours)):
    if marks[i] >= 60:
        result = "Pass"
    else:
        result = "Fail"

    print("Study hours:", study_hours[i], "Mark:", marks[i], "Result:", result)
# Out:
# Study hours: 1 Mark: 50 Result: Fail
# Study hours: 2 Mark: 55 Result: Fail
# Study hours: 3 Mark: 60 Result: Pass
# Study hours: 4 Mark: 65 Result: Pass
# Study hours: 5 Mark: 72 Result: Pass
# Study hours: 6 Mark: 80 Result: Pass
# Study hours: 7 Mark: 88 Result: Pass

# %%
study_hours = [1, 2, 3, 4, 5, 6, 7]
marks = [50, 55, 60, 65, 72, 80, 88]

print("Number of samples:", len(marks))

print("Average study hours:", sum(study_hours) / len(study_hours))

print("Average marks:", sum(marks) / len(marks))

print("Highest mark:", max(marks))
print("Lowest mark:", min(marks))

for i in range(len(study_hours)):
    if marks[i] >= 60:
        result = "Pass"
    else:
        result = "Fail"
    print("Study hours:", study_hours[i], "Mark:", marks[i], "Result:", result)

passes = 0

for mark in marks:
    if mark >= 60:
        passes += 1

print("Number of passes:", passes)
# Out:
# Number of samples: 7
# Average study hours: 4.0
# Average marks: 67.14285714285714
# Highest mark: 88
# Lowest mark: 50
# Study hours: 1 Mark: 50 Result: Fail
# Study hours: 2 Mark: 55 Result: Fail
# Study hours: 3 Mark: 60 Result: Pass
# Study hours: 4 Mark: 65 Result: Pass
# Study hours: 5 Mark: 72 Result: Pass
# Study hours: 6 Mark: 80 Result: Pass
# Study hours: 7 Mark: 88 Result: Pass
# Number of passes: 5
